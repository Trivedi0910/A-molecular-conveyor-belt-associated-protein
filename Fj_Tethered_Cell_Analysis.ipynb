# %%
import numpy as np
import pandas as pd
import pims
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('CentroidPC14.csv')

# %%
sns.scatterplot(data = df, x = 'x', y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df2= pd.read_csv('PC14.csv')

# %%
plt.hist(df2)
# Out:
# (array([ 2.,  2.,  5.,  6., 13.,  6.,  3.,  3.,  2.,  2.]),
#  array([0.40608 , 0.606102, 0.806124, 1.006146, 1.206168, 1.40619 ,
#         1.606212, 1.806234, 2.006256, 2.206278, 2.4063  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df2)

# %%
df3=df2[(df2<=0.0)]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [Speed]
# Index: []

# %%
df4=df2[(df2>=0.0)]

# %%
df5=df4.dropna()

# %%
plt.hist(df5)
# Out:
# (array([ 2.,  2.,  5.,  6., 13.,  6.,  3.,  3.,  2.,  2.]),
#  array([0.40608 , 0.606102, 0.806124, 1.006146, 1.206168, 1.40619 ,
#         1.606212, 1.806234, 2.006256, 2.206278, 2.4063  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df5)

# %%
speed = df5.loc[:,'Speed']

# %%
from distfit import distfit
dist = distfit()
speed2 = distfit(distr='norm')
speed3 = distfit(distr='genextreme')
speed2.fit_transform(speed)
speed3.fit_transform(speed)
dist.fit_transform(speed)
plt.hist(speed)
plt.show()
speed2.plot()
plt.show()
speed3.plot()
plt.show()
mu2=speed2.model['loc']
mu3=speed3.model['loc']
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm] [0.00 sec] [RSS: 12.6145] [loc=1.345 scale=0.431]
# [distfit] >Compute confidence interval [parametric]
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[genextreme] [0.07 sec] [RSS: 12.5689] [loc=1.183 scale=0.417]
# [distfit] >Compute confidence interval [parametric]
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.00 sec] [RSS: 12.6145] [loc=1.345 scale=0.431]
# [distfit] >[expon     ] [0.00 sec] [RSS: 21.1618] [loc=0.406 scale=0.939]
# [distfit] >[pareto    ] [0.02 sec] [RSS: 24.8107] [loc=-0.532 scale=0.939]
# [distfit] >[dweibull  ] [0.03 sec] [RSS: 9.87784] [loc=1.292 scale=0.323]
# [distfit] >[t         ] [0.03 sec] [RSS: 12.6143] [loc=1.345 scale=0.431]
# [distfit] >[genextreme] [0.05 sec] [RSS: 12.5689] [loc=1.183 scale=0.417]
# [distfit] >[gamma     ] [0.02 sec] [RSS: 12.4587] [loc=-2.774 scale=0.045]
# [distfit] >[lognorm   ] [0.05 sec] [RSS: 12.4478] [loc=-4.656 scale=5.986]
# [distfit] >[beta      ] [0.04 sec] [RSS: 12.4587] [loc=-2.774 scale=5005943.136]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 17.1966] [loc=0.406 scale=2.000]
# [distfit] >[loggamma  ] [0.06 sec] [RSS: 12.6573] [loc=-114.283 scale=16.025]
# [distfit] >Compute confidence interval [parametric]
# [distfit] >plot..
# [distfit] >plot..

# %%
mu2, mu3
# Out:
# (1.3452043181818178, 1.1830647517904165)
